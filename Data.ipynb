# %%
import os
import hashlib
from PIL import Image
import shutil

def deduplicate_images(source_dir, clean_dir, duplicates_dir):
    """
    Finds and separates duplicate images from a source directory.

    Args:
        source_dir (str): The folder containing the original dataset (e.g., 'dataset_full').
        clean_dir (str): Where to save the unique images.
        duplicates_dir (str): Where to move the found duplicates.
    """
    if not os.path.exists(clean_dir):
        os.makedirs(clean_dir)
    if not os.path.exists(duplicates_dir):
        os.makedirs(duplicates_dir)

    hashes = {}
    total_files = 0
    duplicate_count = 0

    print(f"Starting de-duplication of '{source_dir}'...")

    # Walk through all subdirectories and files
    for dirpath, _, filenames in os.walk(source_dir):
        # Create corresponding subdirectories in clean and duplicates folders
        structure_clean = os.path.join(clean_dir, os.path.relpath(dirpath, source_dir))
        structure_duplicates = os.path.join(duplicates_dir, os.path.relpath(dirpath, source_dir))
        if not os.path.isdir(structure_clean):
            os.makedirs(structure_clean)
        if not os.path.isdir(structure_duplicates):
            os.makedirs(structure_duplicates)

        for filename in filenames:
            total_files += 1
            path = os.path.join(dirpath, filename)
            try:
                with Image.open(path) as im:
                    im = im.convert("RGB")
                    data = im.tobytes()
                    file_hash = hashlib.md5(data).hexdigest()

                # If we've seen this hash before, it's a duplicate
                if file_hash in hashes:
                    print(f"  DUPLICATE: '{path}' is a copy of '{hashes[file_hash]}'")
                    shutil.move(path, os.path.join(structure_duplicates, filename))
                    duplicate_count += 1
                else:
                    # If it's a new hash, keep it and copy the file
                    hashes[file_hash] = path
                    shutil.copy2(path, os.path.join(structure_clean, filename))

            except Exception as e:
                print(f"Could not process {path}: {e}")

    print("\n--- De-duplication Complete ---")
    print(f"Total files scanned: {total_files}")
    print(f"Unique images found: {len(hashes)}")
    print(f"Duplicates moved: {duplicate_count}")
    print(f"Clean dataset saved to: '{clean_dir}'")

# --- CONFIGURE AND RUN ---
# 1. Your original dataset with all the duplicates
source_dataset_folder = "Diabaticeye"

# 2. A new folder where the clean, unique images will be saved
clean_dataset_folder = "dataset_clean"

# 3. A folder to store the duplicates for inspection
duplicates_folder = "dataset_duplicates"

deduplicate_images(source_dataset_folder, clean_dataset_folder, duplicates_folder)
# Out:
# Starting de-duplication of 'Diabaticeye'...
#   DUPLICATE: 'Diabaticeye\Mild\19e350c7c83c.png' is a copy of 'Diabaticeye\Mild\19722bff5a09.png'
#   DUPLICATE: 'Diabaticeye\Mild\3044022c6969.png' is a copy of 'Diabaticeye\Mild\04ac765f91a1.png'
#   DUPLICATE: 'Diabaticeye\Mild\33105f9b3a04.png' is a copy of 'Diabaticeye\Mild\111898ab463d.png'
#   DUPLICATE: 'Diabaticeye\Mild\595446774178.png' is a copy of 'Diabaticeye\Mild\36041171f441.png'
#   DUPLICATE: 'Diabaticeye\Mild\63a03880939c.png' is a copy of 'Diabaticeye\Mild\05a5183c92d0.png'
#   DUPLICATE: 'Diabaticeye\Mild\6b00cb764237.png' is a copy of 'Diabaticeye\Mild\64678182d8a8.png'
#   DUPLICATE: 'Diabaticeye\Mild\77a9538b8362.png' is a copy of 'Diabaticeye\Mild\40e9b5630438.png'
#   DUPLICATE: 'Diabaticeye\Mild\79ce83c07588.png' is a copy of 'Diabaticeye\Mild\71c1a3cdbe47.png'
#   DUPLICATE: 'Diabaticeye\Mild\7bf981d9c7fe.png' is a copy of 'Diabaticeye\Mild\36677b70b1ef.png'
#   DUPLICATE: 'Diabaticeye\Mild\94372043d55b.png' is a copy of 'Diabaticeye\Mild\0dce95217626.png'
#   DUPLICATE: 'Diabaticeye\Mild\94b1d8ad35ec.png' is a copy of 'Diabaticeye\Mild\4d7d6928534a.png'
#   DUPLICATE: 'Diabaticeye\Mild\a47432cd41e7.png' is a copy of 'Diabaticeye\Mild\1e8a1fdee5b9.png'
#   DUPLICATE: 'Diabaticeye\Mild\a8582e346df0.png' is a copy of 'Diabaticeye\Mild\7a3ea1779b13.png'
#   DUPLICATE: 'Diabaticeye\Mild\b8ebedd382de.png' is a copy of 'Diabaticeye\Mild\1e8a1fdee5b9.png'
#   DUPLICATE: 'Diabaticeye\Mild\c027e5482e8c.png' is a copy of 'Diabaticeye\Mild\7a3ea1779b13.png'
#   DUPLICATE: 'Diabaticeye\Mild\ca25745942b0.png' is a copy of 'Diabaticeye\Mild\00cb6555d108.png'
#   DUPLICATE: 'Diabaticeye\Mild\ca6842bfcbc9.png' is a copy of 'Diabaticeye\Mild\7a3ea1779b13.png'
#   DUPLICATE: 'Diabaticeye\Mild\cc12453ea915.png' is a copy of 'Diabaticeye\Mild\65e51e18242b.png'
#   DUPLICATE: 'Diabaticeye\Mild\d1cad012a254.png' is a copy of 'Diabaticeye\Mild\8fc09fecd22f.png'
#   DUPLICATE: 'Diabaticeye\Mild\d567a1a22d33.png' is a copy of 'Diabaticeye\Mild\12e3f5f2cb17.png'
#   DUPLICATE: 'Diabaticeye\Mild\d801c0a66738.png' is a copy of 'Diabaticeye\Mild\68332fdcaa70.png'
#   DUPLICATE: 'Diabaticeye\Mild\fea14b3d44b0.png' is a copy of 'Diabaticeye\Mild\80d24897669f.png'
#   DUPLICATE: 'Diabaticeye\Moderate\1632c4311fc9.png' is a copy of 'Diabaticeye\Mild\a75bab2463d4.png'
#   DUPLICATE: 'Diabaticeye\Moderate\1c4d87baaffc.png' is a copy of 'Diabaticeye\Mild\35aa7f5c2ec0.png'
#   DUPLICATE: 'Diabaticeye\Moderate\1e143fa3de57.png' is a copy of 'Diabaticeye\Moderate\144b01e7b993.png'
#   DUPLICATE: 'Diabaticeye\Moderate\1f07dae3cadb.png' is a copy of 'Diabaticeye\Moderate\012a242ac6ff.png'
#   DUPLICATE: 'Diabaticeye\Moderate\2b21d293fdf2.png' is a copy of 'Diabaticeye\Moderate\2a3a1ed1c285.png'
#   DUPLICATE: 'Diabaticeye\Moderate\2c2aa057afc5.png' is a copy of 'Diabaticeye\Moderate\135575dc57c9.png'
#   DUPLICATE: 'Diabaticeye\Moderate\36ec36c301c1.png' is a copy of 'Diabaticeye\Moderate\26e231747848.png'
#   DUPLICATE: 'Diabaticeye\Moderate\38fe9f854046.png' is a copy of 'Diabaticeye\Moderate\1dfbede13143.png'
#   DUPLICATE: 'Diabaticeye\Moderate\3c53198519f7.png' is a copy of 'Diabaticeye\Moderate\1c5e6cdc7ee1.png'
#   DUPLICATE: 'Diabaticeye\Moderate\3e86335bc2fd.png' is a copy of 'Diabaticeye\Moderate\0c7e82daf5a0.png'
#   DUPLICATE: 'Diabaticeye\Moderate\42a850acd2ac.png' is a copy of 'Diabaticeye\Mild\51131b48f9d4.png'
#   DUPLICATE: 'Diabaticeye\Moderate\435d900fa7b2.png' is a copy of 'Diabaticeye\Moderate\1006345f70b7.png'
#   DUPLICATE: 'Diabaticeye\Moderate\5a36cea278ae.png' is a copy of 'Diabaticeye\Moderate\1ae8c165fd53.png'
#   DUPLICATE: 'Diabaticeye\Moderate\6cb98da77e3e.png' is a copy of 'Diabaticeye\Moderate\48c49f662f7d.png'
#   DUPLICATE: 'Diabaticeye\Moderate\81b0a2651c45.png' is a copy of 'Diabaticeye\Moderate\07419eddd6be.png'
#   DUPLICATE: 'Diabaticeye\Moderate\8446826853d0.png' is a copy of 'Diabaticeye\Mild\8ef2eb8c51c4.png'
#   DUPLICATE: 'Diabaticeye\Moderate\857002ed4e49.png' is a copy of 'Diabaticeye\Moderate\840527bc6628.png'
#   DUPLICATE: 'Diabaticeye\Moderate\86b3a7929bec.png' is a copy of 'Diabaticeye\Moderate\1b4625877527.png'
#   DUPLICATE: 'Diabaticeye\Moderate\86baef833ae0.png' is a copy of 'Diabaticeye\Moderate\7a0cff4c24b2.png'
#   DUPLICATE: 'Diabaticeye\Moderate\878a3a097436.png' is a copy of 'Diabaticeye\Moderate\80feb1f7ca5e.png'
#   DUPLICATE: 'Diabaticeye\Moderate\8a759f94613a.png' is a copy of 'Diabaticeye\Moderate\2cceb07ff706.png'
#   DUPLICATE: 'Diabaticeye\Moderate\8acffaf1f4b9.png' is a copy of 'Diabaticeye\Moderate\1411c8ab7161.png'
#   DUPLICATE: 'Diabaticeye\Moderate\8cb6b0efaaac.png' is a copy of 'Diabaticeye\Mild\51131b48f9d4.png'
#   DUPLICATE: 'Diabaticeye\Moderate\8d7bb0649a02.png' is a copy of 'Diabaticeye\Moderate\7550966ef777.png'
#   DUPLICATE: 'Diabaticeye\Moderate\91cbe1c775ef.png' is a copy of 'Diabaticeye\Moderate\7d261f986bef.png'
#   DUPLICATE: 'Diabaticeye\Moderate\92b0d27fc0ec.png' is a copy of 'Diabaticeye\Moderate\1a1b4b2450ca.png'
#   DUPLICATE: 'Diabaticeye\Moderate\98104c8c67eb.png' is a copy of 'Diabaticeye\Moderate\75a7bc945b7d.png'
#   DUPLICATE: 'Diabaticeye\Moderate\98e8adcf085c.png' is a copy of 'Diabaticeye\Moderate\026dcd9af143.png'
#   DUPLICATE: 'Diabaticeye\Moderate\9f4132bd6ed6.png' is a copy of 'Diabaticeye\Moderate\9b7b6e4db1d5.png'
#   DUPLICATE: 'Diabaticeye\Moderate\a15652b22ab8.png' is a copy of 'Diabaticeye\Moderate\9b32e8ef0ca0.png'
#   DUPLICATE: 'Diabaticeye\Moderate\a19507501b40.png' is a copy of 'Diabaticeye\Moderate\3a1d3ce00f0c.png'
#   DUPLICATE: 'Diabaticeye\Moderate\a3b2e93d058b.png' is a copy of 'Diabaticeye\Moderate\3fd7df6099e3.png'
#   DUPLICATE: 'Diabaticeye\Moderate\a56230242a95.png' is a copy of 'Diabaticeye\Moderate\1c6d119c3d70.png'
#   DUPLICATE: 'Diabaticeye\Moderate\a7b0d0c51731.png' is a copy of 'Diabaticeye\Moderate\1cb814ed6332.png'
#   DUPLICATE: 'Diabaticeye\Moderate\b376def52ccc.png' is a copy of 'Diabaticeye\Moderate\38487e1a5b1f.png'
#   DUPLICATE: 'Diabaticeye\Moderate\ba2624883599.png' is a copy of 'Diabaticeye\Moderate\14515b8f19b6.png'
#   DUPLICATE: 'Diabaticeye\Moderate\be161517d3ac.png' is a copy of 'Diabaticeye\Moderate\9b418ce42c13.png'
#   DUPLICATE: 'Diabaticeye\Moderate\c05b7b4c22fe.png' is a copy of 'Diabaticeye\Moderate\aca88f566228.png'
#   DUPLICATE: 'Diabaticeye\Moderate\c1c8550508e0.png' is a copy of 'Diabaticeye\Moderate\530d78467615.png'
#   DUPLICATE: 'Diabaticeye\Moderate\c2d2b4f536da.png' is a copy of 'Diabaticeye\Moderate\1ee1eb7943db.png'
#   DUPLICATE: 'Diabaticeye\Moderate\c68dfa021d62.png' is a copy of 'Diabaticeye\Moderate\4ce74e5eb51d.png'
#   DUPLICATE: 'Diabaticeye\Moderate\c9f0dc2c8b43.png' is a copy of 'Diabaticeye\Moderate\9c5dd3612f0c.png'
#   DUPLICATE: 'Diabaticeye\Moderate\cac40227d3b2.png' is a copy of 'Diabaticeye\Moderate\0161338f53cc.png'
#   DUPLICATE: 'Diabaticeye\Moderate\cd4e7f9fa1a9.png' is a copy of 'Diabaticeye\Moderate\9f1efb799b7b.png'
#   DUPLICATE: 'Diabaticeye\Moderate\d144144a2f3f.png' is a copy of 'Diabaticeye\Moderate\b06dabab4f09.png'
#   DUPLICATE: 'Diabaticeye\Moderate\d81b6ed83bc2.png' is a copy of 'Diabaticeye\Moderate\cd3fd04d72f5.png'
#   DUPLICATE: 'Diabaticeye\Moderate\d994203deb64.png' is a copy of 'Diabaticeye\Moderate\a505981d1cab.png'
#   DUPLICATE: 'Diabaticeye\Moderate\da0a1043abf7.png' is a copy of 'Diabaticeye\Moderate\b13d72ceea26.png'
#   DUPLICATE: 'Diabaticeye\Moderate\dc3c0d8ee20b.png' is a copy of 'Diabaticeye\Moderate\ca891d37a43c.png'
#   DUPLICATE: 'Diabaticeye\Moderate\e12d41e7b221.png' is a copy of 'Diabaticeye\Mild\bacfb1029f6b.png'
#   DUPLICATE: 'Diabaticeye\Moderate\e4e343eaae2a.png' is a copy of 'Diabaticeye\Moderate\43fb6eda9b97.png'
#   DUPLICATE: 'Diabaticeye\Moderate\e7a7187066ad.png' is a copy of 'Diabaticeye\Moderate\ce887b196c23.png'
#   DUPLICATE: 'Diabaticeye\Moderate\ea05c22d92e9.png' is a copy of 'Diabaticeye\Moderate\ca0f1a17c8e5.png'
#   DUPLICATE: 'Diabaticeye\Moderate\ea9e0fb6fb0b.png' is a copy of 'Diabaticeye\Moderate\23d7ca170bdb.png'
#   DUPLICATE: 'Diabaticeye\Moderate\ee2c2a5f7d0e.png' is a copy of 'Diabaticeye\Moderate\7877be80901c.png'
#   DUPLICATE: 'Diabaticeye\Moderate\f4d3777f2710.png' is a copy of 'Diabaticeye\Moderate\5dc23e440de3.png'
#   DUPLICATE: 'Diabaticeye\Moderate\f920ccd926db.png' is a copy of 'Diabaticeye\Moderate\bcdc8db5423b.png'
#   DUPLICATE: 'Diabaticeye\Moderate\f9ecf1795804.png' is a copy of 'Diabaticeye\Moderate\d28bd830c171.png'
#   DUPLICATE: 'Diabaticeye\Moderate\ff0740cb484a.png' is a copy of 'Diabaticeye\Moderate\b8ac328009e0.png'
#   DUPLICATE: 'Diabaticeye\Moderate\ff52392372d3.png' is a copy of 'Diabaticeye\Moderate\f1a761c68559.png'
#   DUPLICATE: 'Diabaticeye\No_DR\1c9c583c10bf.png' is a copy of 'Diabaticeye\Mild\ea15a290eb96.png'
#   DUPLICATE: 'Diabaticeye\No_DR\42985aa2e32f.png' is a copy of 'Diabaticeye\Mild\6165081b9021.png'
#   DUPLICATE: 'Diabaticeye\No_DR\a4012932e18d.png' is a copy of 'Diabaticeye\No_DR\906d02fb822d.png'
#   DUPLICATE: 'Diabaticeye\No_DR\badb5ff8d3c7.png' is a copy of 'Diabaticeye\No_DR\2923971566fe.png'
#   DUPLICATE: 'Diabaticeye\No_DR\c546670d9684.png' is a copy of 'Diabaticeye\Mild\30cab14951ac.png'
#   DUPLICATE: 'Diabaticeye\No_DR\d51c2153d151.png' is a copy of 'Diabaticeye\No_DR\7b691d9ced34.png'
#   DUPLICATE: 'Diabaticeye\No_DR\e2c3b037413b.png' is a copy of 'Diabaticeye\No_DR\a8b637abd96b.png'
#   DUPLICATE: 'Diabaticeye\No_DR\f066db7a2efe.png' is a copy of 'Diabaticeye\Mild\278aa860dffd.png'
#   DUPLICATE: 'Diabaticeye\No_DR\f9e1c439d4c8.png' is a copy of 'Diabaticeye\No_DR\3f44d749cd0b.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\2df07eb5779f.png' is a copy of 'Diabaticeye\Moderate\b91ef82e723a.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\3ca637fddd56.png' is a copy of 'Diabaticeye\Proliferate_DR\3b4a5fcbe5e0.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\3ee4841936ef.png' is a copy of 'Diabaticeye\Mild\7005be54cab1.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\46cdc8b685bd.png' is a copy of 'Diabaticeye\Moderate\e4151feb8443.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\576e189d23d4.png' is a copy of 'Diabaticeye\Proliferate_DR\1638404f385c.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\5e7db41b3bee.png' is a copy of 'Diabaticeye\Moderate\a1b12fdce6c3.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\65c958379680.png' is a copy of 'Diabaticeye\Proliferate_DR\11242a67122d.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\80964d8e0863.png' is a copy of 'Diabaticeye\Moderate\ab50123abadb.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\9e3510963315.png' is a copy of 'Diabaticeye\Moderate\b187b3c93afb.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\bd5013540a13.png' is a copy of 'Diabaticeye\Proliferate_DR\22895c89792f.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\c0e509786f7f.png' is a copy of 'Diabaticeye\Proliferate_DR\aeed1f251ceb.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\c8d2d32f7f29.png' is a copy of 'Diabaticeye\Proliferate_DR\034cb07a550f.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\d85ea1220a03.png' is a copy of 'Diabaticeye\Proliferate_DR\bfefa7344e7d.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\df4913ca3712.png' is a copy of 'Diabaticeye\Proliferate_DR\d51b3fe0fa1b.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\e037643244b7.png' is a copy of 'Diabaticeye\Proliferate_DR\5b76117c4bcb.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\e39b627cf648.png' is a copy of 'Diabaticeye\Moderate\b9127e38d9b9.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\e740af6ac6ea.png' is a copy of 'Diabaticeye\Moderate\98f7136d2e7a.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\eadc57064154.png' is a copy of 'Diabaticeye\Proliferate_DR\6c3745a222da.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\ed3a0fc5b546.png' is a copy of 'Diabaticeye\Proliferate_DR\ba735b286d62.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\f03d3c4ce7fb.png' is a copy of 'Diabaticeye\Moderate\9a3c03a5ad0f.png'
#   DUPLICATE: 'Diabaticeye\Proliferate_DR\f6f3ea0d2693.png' is a copy of 'Diabaticeye\Proliferate_DR\1e9224ccca95.png'
#   DUPLICATE: 'Diabaticeye\Severe\0cb14014117d.png' is a copy of 'Diabaticeye\Moderate\4a44cc840ebe.png'
#   DUPLICATE: 'Diabaticeye\Severe\14e3f84445f7.png' is a copy of 'Diabaticeye\Proliferate_DR\f0f89314e860.png'
#   DUPLICATE: 'Diabaticeye\Severe\4fecf87184e6.png' is a copy of 'Diabaticeye\Moderate\f7edc074f06b.png'
#   DUPLICATE: 'Diabaticeye\Severe\6253f23229b1.png' is a copy of 'Diabaticeye\Moderate\76cfe8967f7d.png'
#   DUPLICATE: 'Diabaticeye\Severe\7525ebb3434d.png' is a copy of 'Diabaticeye\Moderate\3cd801ffdbf0.png'
#   DUPLICATE: 'Diabaticeye\Severe\91b6ebaa3678.png' is a copy of 'Diabaticeye\Severe\7e160c8b611e.png'
#   DUPLICATE: 'Diabaticeye\Severe\9bf060db8376.png' is a copy of 'Diabaticeye\Moderate\f7edc074f06b.png'
#   DUPLICATE: 'Diabaticeye\Severe\9c52b87d01f1.png' is a copy of 'Diabaticeye\Severe\6e92b1c5ac8e.png'
#   DUPLICATE: 'Diabaticeye\Severe\a8e88d4891c4.png' is a copy of 'Diabaticeye\Proliferate_DR\2f7789c1e046.png'
#   DUPLICATE: 'Diabaticeye\Severe\a9e984b57556.png' is a copy of 'Diabaticeye\Moderate\5eb311bcb5f9.png'
#   DUPLICATE: 'Diabaticeye\Severe\d0079cc188e9.png' is a copy of 'Diabaticeye\Moderate\3dbfbc11e105.png'
#   DUPLICATE: 'Diabaticeye\Severe\e76a9cbb2a8c.png' is a copy of 'Diabaticeye\Severe\bb7e0a2544cd.png'
#   DUPLICATE: 'Diabaticeye\Severe\e8d1c6c07cf2.png' is a copy of 'Diabaticeye\Moderate\f23902998c21.png'
#   DUPLICATE: 'Diabaticeye\Severe\fcc6aa6755e6.png' is a copy of 'Diabaticeye\Proliferate_DR\60f15dd68d30.png'
#   DUPLICATE: 'Diabaticeye\Severe\fda39982a810.png' is a copy of 'Diabaticeye\Moderate\0ac436400db4.png'
#   DUPLICATE: 'Diabaticeye\Severe\fe0fc67c7980.png' is a copy of 'Diabaticeye\Moderate\521d3e264d71.png'
#
# --- De-duplication Complete ---
# Total files scanned: 3662
# Unique images found: 3534
# Duplicates moved: 128
# Clean dataset saved to: 'dataset_clean'

# %%
import splitfolders

# The location of your single, combined dataset
input_folder = "dataset_clean"

# The location where you want the new split dataset
output_folder = "dataset_split"

# This will split the data into 80% training, 10% validation, and 10% testing
# It ensures no files are shared between them.
# The 'stratify' option is not needed as the library does it by default.
splitfolders.ratio(
    input_folder,
    output=output_folder,
    seed=42,  # A fixed seed ensures the split is the same every time you run it
    ratio=(0.8, 0.1, 0.1)  # 80% train, 10% validation, 10% test
)

print("Dataset has been split successfully!")
# Out:
# Copying files: 3534 files [00:01, 3310.48 files/s]
# Dataset has been split successfully!

# %%
import os

def find_overlap(train_dir, test_dir):
    train_files = set()
    for root, _, files in os.walk(train_dir):
        for f in files:
            train_files.add(f)
    test_files = set()
    for root, _, files in os.walk(test_dir):
        for f in files:
            if f in train_files:
                print("Exact filename overlap:", f)
find_overlap("dataset_split/train", "dataset_split/test")

# %%
from PIL import Image
import os
import hashlib

def img_hash(path):
    with Image.open(path) as im:
        im = im.convert("RGB")
        data = im.tobytes()
    return hashlib.md5(data).hexdigest()

def find_pixel_duplicates(train_dir, test_dir):
    train_hashes = {}
    for root, _, files in os.walk(train_dir):
        for f in files:
            p = os.path.join(root, f)
            try:
                h = img_hash(p)
                train_hashes.setdefault(h, []).append(p)
            except Exception:
                pass

    for root, _, files in os.walk(test_dir):
        for f in files:
            p = os.path.join(root, f)
            try:
                h = img_hash(p)
                if h in train_hashes:
                    print("Pixel duplicate found:", p, "matches", train_hashes[h][:3])
            except Exception:
                pass

find_pixel_duplicates("dataset_split/train", "dataset_split/test")
